# %% [markdown]
# # Explore here

# %%
#conectar con la API de Spotify
import os
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# load the .env file variables
load_dotenv()

client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id, client_secret=client_secret, redirect_uri="https://apids4geeks.com/callback"))

# %%
#obtener top 10 de canciones de tu artista favorito (en este caso Artic Monkeys)
id_artista = "7Ln80lUS6He07XvHI8qqHH"

respuesta = sp.artist_top_tracks(id_artista)

tracks = respuesta["tracks"]

# %%
#guardar los tracks en un data frame de pandas
df_tracks = pd.DataFrame.from_records(tracks)
df_tracks
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
#ordenar los tracks por popularidad

df_tracks.sort_values(["popularity"], inplace=True)
df_tracks
# Out:
#                                                album  \
# 9  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
#mostrar el top 3 del data frame

df_tracks.head(3)
# Out:
#                                                album  \
# 9  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 9       173680     False  {'isrc': 'GBCEL0501181'}
# 8       257563     False  {'isrc': 'GBCEL1300372'}
# 7       207356     False  {'isrc': 'GBCEL1300365'}
#
#                                        external_urls  \
# 9  {'spotify': 'https://open.spotify.com/track/3D...
# 8  {'spotify': 'https://open.spotify.com/track/2L...
# 7  {'spotify': 'https://open.spotify.com/track/7n...
#
# ...

# %%
#analizar relacion estadistica entre la duración y la popularidad
import matplotlib.pyplot as plt

plt.scatter(x=df_tracks["popularity"], y=df_tracks["duration_ms"])
plt.show()

# %% [markdown]
# No se observa relacion entre la duracion de la cancion y su popularidad
